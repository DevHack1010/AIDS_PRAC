# %%
import matplotlib.pyplot as plt

epochs=[1,2,3,4,5]
accuracy=[0.65,0.72,0.78,0.82,0.88]
plt.plot(epochs,accuracy,marker='o')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
from matplotlib import colors
models = ["LR","SVM","RF","NN"]
accuracy = [0.80,0.85,0.88,0.90]
plt.bar(models,accuracy,color='skyblue')
plt.title('Model Accuracy')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.show()

# %%
import numpy as np
x = np.random.rand(30)
y = np.random.rand(30)
plt.scatter(x,y, c='orange')
plt.title('Scatter Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
classes = ["Cat", "Dog", "Horse"]
samples = [50, 30, 20]

plt.pie(samples, labels=classes, autopct='%1.1f%%')
plt.title('Class Distribution')
plt.show()
